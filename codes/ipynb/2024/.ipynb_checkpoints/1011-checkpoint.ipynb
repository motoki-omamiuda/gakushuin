# %%
using Plots

# %%
plt = plot(
    xlim=(2, 15.), ylim=(-0.00, 0.07),
    legend=false,
    # ratio=1, # アスペクト比を指定
    dpi=800, # 解像度を指定
)

MASS = 1

x_00 = []
y_00 = []
y_01 = []
y_02 = []

x_list = [[], [], []]
y_list = [[], [], []]
k_list = [0.02, 1/27, 0.055]
a = []
b = []
c = 0.02

for i in 0.01:0.01:20
    push!(x_00, i)
    y = 1 / i ^ 2 - 2 * MASS / i ^ 3
    push!(y_00, y)
    
    if c > y && i < 3
        push!(a, c)
        push!(b, i)
    end
    if k_list[1] > y && i > 3
        push!(x_list[1], i)
        push!(y_list[1], k_list[1])
    end
    for j in 2:length(k_list)
        if k_list[j] > y
            push!(x_list[j], i)
            push!(y_list[j], k_list[j])
        end
    end
    
    # push!(y_01, 1 / i ^ 2)
    # push!(y_02, - 2 * MASS / i ^ 3)
end

plot!(plt, x_00, y_00, color=:red, linewidth=3)
plot!(plt, [3, 3], [-100, 100], color=:black, linewidth=1, linestyle=:dot)
plot!(plt, [-100, 100], [0.02, 0.02], color=:black, linewidth=1, linestyle=:dot)
plot!(plt, [-100, 100], [1/27, 1/27], color=:black, linewidth=1, linestyle=:dot)

for (x, y) in zip(x_list, y_list)
    plot!(plt, x, y, color=:blue, linewidth=3)
end
plot!(plt, b, a, color=:blue, linewidth=3)

# plot!(plt, x, y_01, color=:black, linestyle=:dot)
# plot!(plt, x, y_02, color=:black, linestyle=:dot)

plt
savefig(plt, "./1011.png")
# Out:
# "/Users/motoki/Desktop/research/codes/ipynb/202410/1011.png"

# %%
# QuadGK パッケージのインストール（初回のみ必要）
import Pkg
Pkg.add("QuadGK")

# 必要なライブラリを使用
using QuadGK

# 任意の関数を定義 (例: f(x) = x^2)
f(x) = x^2

# 関数を指定された範囲で数値積分
a = 0  # 積分範囲の下限
b = 1  # 積分範囲の上限
result, err = quadgk(f, a, b)

println("積分結果: $result")
println("推定誤差: $err")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed QuadGK ─ v2.11.1
#     Updating `~/.julia/environments/v1.10/Project.toml`
#   [1fd47b50] + QuadGK v2.11.1
#     Updating `~/.julia/environments/v1.10/Manifest.toml`
#   [1fd47b50] ↑ QuadGK v2.9.4 ⇒ v2.11.1
# Precompiling project...
#   ✓ QuadGK
#   ✓ Distributions
#   ✓ Distributions → DistributionsTestExt
#   ✓ Distributions → DistributionsChainRulesCoreExt
#   ✓ DiffEqBase → DiffEqBaseDistributionsExt
#   ✓ BlackBoxOptim
#   ✓ DiffEqNoiseProcess
#   ✓ BlackBoxOptim → BlackBoxOptimRealtimePlotServerExt
#   ✓ StochasticDiffEq
#   ✓ DifferentialEquations
#   10 dependencies successfully precompiled in 45 seconds. 365 already precompiled.
# 積分結果: 0.3333333333333333
# 推定誤差: 0.0

# %%
using QuadGK

b = 10


function P(b)
    var = b ^ 2 * sqrt( Complex(1 - (b ^ 2 / 27)) )
    return (
        (- b ^ 2 + var) ^ (1 / 3) + (- b ^ 2 - var) ^ (1 / 3)
    )
end


function phi(x)
    return sqrt( 1 / ( 2 / ( x ^ 3 ) - 1 / ( x ^ 2 ) + 1 / ( b ^ 2 ) ) )
end


r_list = []
phi_list = []

# print(phi(1))
for i in 2:-0.01:0
    println(i)
#     push!(r_list, i)
#     push!(phi_list, phi(i))
end

for (phi_val, r_val) in zip(phi_list, r_list)
    push!(x_list, r_val * cos(phi_val))
    push!(y_list, r_val * sin(phi_val) )
end

plt = plot(
    xlim=(-15, 15.), ylim=(-15, 15),
    legend=false,
    # ratio=1, # アスペクト比を指定
    dpi=800, # 解像度を指定
)
plot!(plt, x_list, y_list, color=:red, linewidth=3)
plt
# Out:
# 2.0
# 1.99
# 1.98
# 1.97
# 1.96
# 1.95
# 1.94
# 1.93
# 1.92
# 1.91
# 1.9
# 1.89
# 1.88
# 1.87
# 1.86
# 1.85
# 1.84
# 1.83
# 1.82
# 1.81
# 1.8
# 1.79
# 1.78
# 1.77
# 1.76
# 1.75
# 1.74
# 1.73
# 1.72
# 1.71
# 1.7
# 1.69
# 1.68
# 1.67
# 1.66
# 1.65
# 1.64
# 1.63
# 1.62
# 1.61
# 1.6
# 1.59
# 1.58
# 1.57
# 1.56
# 1.55
# 1.54
# 1.53
# 1.52
# 1.51
# 1.5
# 1.49
# 1.48
# 1.47
# 1.46
# 1.45
# 1.44
# 1.43
# 1.42
# 1.41
# 1.4
# 1.39
# 1.38
# 1.37
# 1.36
# 1.35
# 1.34
# 1.33
# 1.32
# 1.31
# 1.3
# 1.29
# 1.28
# 1.27
# 1.26
# 1.25
# 1.24
# 1.23
# 1.22
# 1.21
# 1.2
# 1.19
# 1.18
# 1.17
# 1.16
# 1.15
# 1.14
# 1.13
# 1.12
# 1.11
# 1.1
# 1.09
# 1.08
# 1.07
# 1.06
# 1.05
# 1.04
# 1.03
# 1.02
# 1.01
# 1.0
# 0.99
# 0.98
# 0.97
# 0.96
# 0.95
# 0.94
# 0.93
# 0.92
# 0.91
# 0.9
# 0.89
# 0.88
# 0.87
# 0.86
# 0.85
# 0.84
# 0.83
# 0.82
# 0.81
# 0.8
# 0.79
# 0.78
# 0.77
# 0.76
# 0.75
# 0.74
# 0.73
# 0.72
# 0.71
# 0.7
# 0.69
# 0.68
# 0.67
# 0.66
# 0.65
# 0.64
# 0.63
# 0.62
# 0.61
# 0.6
# 0.59
# 0.58
# 0.57
# 0.56
# 0.55
# 0.54
# 0.53
# 0.52
# 0.51
# 0.5
# 0.49
# 0.48
# 0.47
# 0.46
# 0.45
# 0.44
# 0.43
# 0.42
# 0.41
# 0.4
# 0.39
# 0.38
# 0.37
# 0.36
# 0.35
# 0.34
# 0.33
# 0.32
# 0.31
# 0.3
# 0.29
# 0.28
# 0.27
# 0.26
# 0.25
# 0.24
# 0.23
# 0.22
# 0.21
# 0.2
# 0.19
# 0.18
# 0.17
# 0.16
# 0.15
# 0.14
# 0.13
# 0.12
# 0.11
# 0.1
# 0.09
# 0.08
# 0.07
# 0.06
# 0.05
# 0.04
# 0.03
# 0.02
# 0.01
# 0.0
